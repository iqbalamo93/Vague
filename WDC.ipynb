# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('WDC_Business_Case.csv',error_bad_lines=False,encoding = "Latin-1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
# Product                       80 non-null object
# Channel                       80 non-null object
# Customer Name                 80 non-null int64
# Region                        80 non-null object
# Quarter                       80 non-null object
# Price per unit WD             80 non-null object
# Price per unit distributor    80 non-null object
# Units Sold                    80 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 5.1+ KB

# %%
df['Units Sold']=df['Units Sold'].str.replace(',','')
df['Units Sold']=df['Units Sold'].astype(float)

# %%
df['Units Sold']
# Out:
# 0     4514.0
# 1     5421.0
# 2     4409.0
# 3     5003.0
# 4     7081.0
# 5     7078.0
# 6     4447.0
# 7     4443.0
# 8     5272.0
# 9     5114.0
# 10    3188.0
# 11    6759.0
# 12    5787.0
# 13    6848.0
# 14    3356.0
# 15    4949.0
# 16    4963.0
# 17    6641.0
# 18    5603.0
# 19    2676.0
# 20    7450.0
# 21    3560.0
# 22    7149.0
# 23    4134.0
# 24    5842.0
# 25    2932.0
# 26    2728.0
# 27    4255.0
# 28    3952.0
# 29    4581.0
#        ...
# 50    5321.0
# 51    3836.0
# 52    3628.0
# 53    5971.0
# 54    6452.0
# 55    6821.0
# 56    3851.0
# 57    3985.0
# 58    5284.0
# 59    2533.0
# 60    7197.0
# 61    4513.0
# 62    5482.0
# 63    6322.0
# 64    5206.0
# 65    4140.0
# 66    5818.0
# 67    7362.0
# 68    6909.0
# 69    4293.0
# 70    6341.0
# 71    7492.0
# 72    2649.0
# 73    4395.0
# 74    4850.0
# 75    7008.0
# 76    3190.0
# 77    6179.0
# 78    4975.0
# 79    5839.0
# Name: Units Sold, Length: 80, dtype: float64

# %%
df.columns
# Out:
# Index(['Product', 'Channel', 'Customer Name', 'Region', 'Quarter',
#        'Price per unit WD', 'Price per unit distributor', 'Units Sold'],
#       dtype='object')

# %%
df['Product'].unique()
# Out:
# array(['CoolCharge'], dtype=object)

# %%
df['Channel'].unique()
# Out:
# array(['Brick&Mortar', 'Distribution'], dtype=object)

# %%
df['Customer Name'].unique(),df['Customer Name'].nunique()
# Out:
# (array([ 1003,  1011,  1022,  3011, 32000,  2333,  2332,  5334,  4435,
#          5677], dtype=int64), 10)

# %%
df['Region'].unique(),df['Region'].nunique()
# Out:
# (array(['North America', 'Japan', 'APAC', 'Latin America'], dtype=object), 4)

# %%
df['Quarter'].unique(),df['Quarter'].nunique()
# Out:
# (array(['Q1', 'Q2'], dtype=object), 2)

# %%
df.head(10)
# Out:
#       Product       Channel  Customer Name         Region Quarter  \
# 0  CoolCharge  Brick&Mortar           1003  North America      Q1
# 1  CoolCharge  Brick&Mortar           1003          Japan      Q1
# 2  CoolCharge  Brick&Mortar           1003           APAC      Q1
# 3  CoolCharge  Brick&Mortar           1003  Latin America      Q1
# 4  CoolCharge  Brick&Mortar           1003  North America      Q2
# 5  CoolCharge  Brick&Mortar           1003          Japan      Q2
# 6  CoolCharge  Brick&Mortar           1003           APAC      Q2
# 7  CoolCharge  Brick&Mortar           1003  Latin America      Q2
# 8  CoolCharge  Brick&Mortar           1011  North America      Q1
# 9  CoolCharge  Brick&Mortar           1011          Japan      Q1
#
#   Price per unit WD Price per unit distributor Units Sold
# 0              $18                        $20    4,514.00
# 1              $19                        $21    5,421.00
# 2              $19                        $21    4,409.00
# ...

# %%
df.tail(10)
# Out:
#        Product       Channel  Customer Name         Region Quarter  \
# 70  CoolCharge  Distribution           4435           APAC      Q2
# 71  CoolCharge  Distribution           4435  Latin America      Q2
# 72  CoolCharge  Distribution           5677  North America      Q1
# 73  CoolCharge  Distribution           5677          Japan      Q1
# 74  CoolCharge  Distribution           5677           APAC      Q1
# 75  CoolCharge  Distribution           5677  Latin America      Q1
# 76  CoolCharge  Distribution           5677  North America      Q2
# 77  CoolCharge  Distribution           5677          Japan      Q2
# 78  CoolCharge  Distribution           5677           APAC      Q2
# 79  CoolCharge  Distribution           5677  Latin America      Q2
#
#    Price per unit WD Price per unit distributor Units Sold
# 70              $16                        $21    6,341.00
# 71              $19                        $21    7,492.00
# ...

# %%
df_Region_APAC=df[df['Region']=='APAC']

# %%
df_Region_APAC.reset_index(inplace=True)
df_Region_APAC
# Out:
#     index     Product       Channel  Customer Name Region Quarter  \
# 0       2  CoolCharge  Brick&Mortar           1003   APAC      Q1
# 1       6  CoolCharge  Brick&Mortar           1003   APAC      Q2
# 2      10  CoolCharge  Brick&Mortar           1011   APAC      Q1
# 3      14  CoolCharge  Brick&Mortar           1011   APAC      Q2
# 4      18  CoolCharge  Brick&Mortar           1022   APAC      Q1
# 5      22  CoolCharge  Brick&Mortar           1022   APAC      Q2
# 6      26  CoolCharge  Brick&Mortar           3011   APAC      Q1
# 7      30  CoolCharge  Brick&Mortar           3011   APAC      Q2
# 8      34  CoolCharge  Brick&Mortar          32000   APAC      Q1
# 9      38  CoolCharge  Brick&Mortar          32000   APAC      Q2
# 10     42  CoolCharge  Distribution           2333   APAC      Q1
# 11     46  CoolCharge  Distribution           2333   APAC      Q2
# 12     50  CoolCharge  Distribution           2332   APAC      Q1
# ...

# %%
df_Region_APAC['Delta']=df_Region_APAC['Units Sold'].pct_change()
# Out:
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Region_APAC['Delta'].iloc[::2]=np.NaN
# Out:
# C:\Users\iqbal\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Region_APAC
# Out:
#     index     Product       Channel  Customer Name Region Quarter  \
# 0       2  CoolCharge  Brick&Mortar           1003   APAC      Q1
# 1       6  CoolCharge  Brick&Mortar           1003   APAC      Q2
# 2      10  CoolCharge  Brick&Mortar           1011   APAC      Q1
# 3      14  CoolCharge  Brick&Mortar           1011   APAC      Q2
# 4      18  CoolCharge  Brick&Mortar           1022   APAC      Q1
# 5      22  CoolCharge  Brick&Mortar           1022   APAC      Q2
# 6      26  CoolCharge  Brick&Mortar           3011   APAC      Q1
# 7      30  CoolCharge  Brick&Mortar           3011   APAC      Q2
# 8      34  CoolCharge  Brick&Mortar          32000   APAC      Q1
# 9      38  CoolCharge  Brick&Mortar          32000   APAC      Q2
# 10     42  CoolCharge  Distribution           2333   APAC      Q1
# 11     46  CoolCharge  Distribution           2333   APAC      Q2
# 12     50  CoolCharge  Distribution           2332   APAC      Q1
# ...

# %%
df_Region_LA=df[df['Region']=='Latin America']
df_Region_LA.reset_index(inplace=True)
df_Region_LA['Delta']=df_Region_LA['Units Sold'].pct_change()
df_Region_LA['Delta'].iloc[::2]=np.NaN
df_Region_LA.head(20)
# Out:
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#     index     Product       Channel  Customer Name         Region Quarter  \
# 0       3  CoolCharge  Brick&Mortar           1003  Latin America      Q1
# 1       7  CoolCharge  Brick&Mortar           1003  Latin America      Q2
# ...

# %%
df_Region_Japan=df[df['Region']=='Japan']
df_Region_Japan.reset_index(inplace=True)
df_Region_Japan['Delta']=df_Region_Japan['Units Sold'].pct_change()
df_Region_Japan['Delta'].iloc[::2]=np.NaN
df_Region_Japan.head(20)
# Out:
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#     index     Product       Channel  Customer Name Region Quarter  \
# 0       1  CoolCharge  Brick&Mortar           1003  Japan      Q1
# 1       5  CoolCharge  Brick&Mortar           1003  Japan      Q2
# ...

# %%
df_Region_NA=df[df['Region']=='North America']
df_Region_NA.reset_index(inplace=True)
df_Region_NA['Delta']=df_Region_NA['Units Sold'].pct_change()
df_Region_NA['Delta'].iloc[::2]=np.NaN
df_Region_NA.head(20)
# Out:
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\iqbal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#     index     Product       Channel  Customer Name         Region Quarter  \
# 0       0  CoolCharge  Brick&Mortar           1003  North America      Q1
# 1       4  CoolCharge  Brick&Mortar           1003  North America      Q2
# ...
